# %%
#pandas
import pandas as pd

# %%
#series=index,coloumn
#pd.sreies(coloumn,index)
a=["prani","uma","likki","elaka","geethu","arjun"]
r=pd.Series(a,index=[12,34,67,80,25,35])
print(r)
# Out:
# 12     prani
# 34       uma
# 67     likki
# 80     elaka
# 25    geethu
# 35     arjun
# dtype: object

# %%
dia=pd.read_csv("/content/diabetcsv.csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dia=pd.read_csv("/content/grades_withnulls.txt",sep=",")
dia
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
dia=pd.read_excel("/content/diabetes.xlsx")
gra=pd.read_csv("/content/demodt.txt")
print(dia)
print(gra)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# ...

# %%
pol=pd.read_csv("/content/demodt.txt")
print(pol)
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
dia=pd.read_excel("/content/diabetes.xlsx",sheet_name="dora")
print(dia)
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
gra.describe()
# Out:
#         Literacy  Cleanliness  Crime_Rate       Good
# count  26.000000    26.000000   26.000000  26.000000
# mean   75.269231    77.038462   52.307692   0.423077
# std    12.078270     8.879103    6.208183   0.503831
# min    55.000000    63.000000   41.000000   0.000000
# 25%    67.250000    69.250000   47.250000   0.000000
# 50%    75.500000    77.500000   52.000000   0.000000
# 75%    84.750000    83.750000   57.000000   1.000000
# max    94.000000    92.000000   63.000000   1.000000

# %%
df=pd.read_csv("/content/grades_withnulls.txt")
df
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
df=pd.read_csv("/content/diabetcsv.csv")
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
print(df.isnull())
# Out:
#       preg   plas   pres   skin   insu   mass   pedi    age  class
# 0    False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 763  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False
# 767  False  False  False  False  False  False  False  False  False
#
# [768 rows x 9 columns]

# %%
print(df.isnull().sum())
# Out:
# preg     0
# plas     0
# pres     0
# skin     0
# insu     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
mdf=df.dropna()
mdf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555,inplace=True)
df2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df['SEM1'].mean()
print(mv)
df2.fillna(mv,inplace=True)
df2
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#iloc=intrgrt location,index
#loc=feild names,index
df.loc[0]#first record names
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
df.loc[0:5]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1

# %%
df.loc[5:7,"SEM1"]
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
df.iloc[10:12,0:2]

# %%
df[df.Grade=='A']

# %%
#print record who scored 9.3 in SEM3
df[df.SEM3==9.3]

# %%
df.loc[df['SEM1']>9.8,['Names']]

# %%
#access the grades of students who score more than 9.7 in sem3
df.loc[df['SEM3']>9.7,['Grade']]
#accessing the records of sem3>9.7 but printing only grader column
# Out:
#    Grade
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A

# %%
df.drop_duplicates(inplace=True)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   average
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# ...

# %%
df.tail(7)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   average
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# 12   Jolin        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 14    Riya        M   9.3   9.9  10.0     A       1    Good  9.733333
# 15    Sana        V   9.9   9.3   9.2     A       0    Good  9.466667
# 16    Mark        N   7.7   8.0   7.0     B       0    Good  7.566667

# %%
df.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   average
# 0     Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1  Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2  Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3    Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4    Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5     Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6  Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667

# %%
#accessingnusing index function
print(df[df.index==7])
print(df.loc[df.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct  average
# 7  Mari        N   7.7   8.0   7.1     B       1    Good      7.6
# 7    B
# Name: Grade, dtype: object

# %%
colnames=df.columns
print(colnames)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed',
#        'conduct', 'average'],
#       dtype='object')

# %%
colnames=list(df.columns)
print(colnames)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed', 'conduct', 'average']

# %%
df.rename(columns={"Grade":"GPA"})
df.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed',
#        'conduct', 'average'],
#       dtype='object')

# %%
#create a new column
#dfname['newcolumn']=values
df["conduct"]="Good"
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good
# 3     Mary        N   7.7   8.0   NaN     B       0    Good
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good
# 5      Raj        M   8.9   9.1   9.3     A       1    Good
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good
# 7     Mari        N   7.7   8.0   7.1     B       1    Good
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good
# 11    Maya        N   7.7   8.0   7.1     B       0    Good
# 12   Jolin        K   9.8   9.1   9.9    A+       1    Good
# 13  Rajesh        M   8.9   9.1   9.3     A       1    Good
# 14    Riya        M   9.3   9.9  10.0     A       1    Good
# ...

# %%
#Create a new column avetage with the avg value of sem1,2,3
df["average"]=(df['SEM1']+df['SEM2']+df['SEM3'])/3
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   average
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# ...

# %%
#DATA VISUALISATION USING PANDAS
df[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
df[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df[['SEM1','SEM2']].plot.line(subplots=True)
df.plot.line()
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot(kind="scatter",x="average",y="Names")
# Out:
# <Axes: xlabel='average', ylabel='Names'>

# %%
df.plot(kind="line",x="Names",y="average")
# Out:
# <Axes: xlabel='Names'>

# %%
df.plot(kind="hist",x="Names",y="average")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv("df.csv")
#dfname.to_csv("filename")
