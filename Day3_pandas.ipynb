# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv("/content/df.csv")
df
# Out:
#     Unnamed: 0   Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct  \
# 0            0     Joe        K   9.8  10.0   9.9    A+       1    Good
# 1            1  Rajesh        M   8.9   9.1   9.3     A       1    Good
# 2            2  Kissan        V   9.9   9.8  10.0     A       0    Good
# 3            3    Mary        N   7.7   8.0   NaN     B       0    Good
# 4            4    Jeen        K   9.8   9.1   9.9    A+       1    Good
# 5            5     Raj        M   8.9   9.1   9.3     A       1    Good
# 6            6  Hassan        V   9.9   9.0   9.2     A       1    Good
# 7            7    Mari        N   7.7   8.0   7.1     B       1    Good
# 8            8    Jess        K   NaN   9.1   9.9    A+       1    Good
# 9            9  Rajini        M   NaN   9.1   9.3     A       0    Good
# 10          10   Kiran        V   NaN   9.3   9.2     A       0    Good
# 11          11    Maya        N   7.7   8.0   7.1     B       0    Good
# ...

# %%
p1=sns.lineplot(x='Names',y='SEM1',data=df)

# %%
sns.relplot(data=df,x="SEM1",y="Names",col="Placed")

# %%
sb=pd.read_excel("/content/diabetes.xlsx")
sb
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
#create a relatitonal plot using age as y axis and index as x axis seperated by class
sb=pd.read_excel("/content/diabetes.xlsx")
sb["index"]=range(0,768)
sb=sns.relplot(data=sb,x="index",y="age",col='class')

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='size',style='time',palette="bright")

# %%
abc=sns.load_dataset("dowjones")
sns.relplot(data=abc,x='Date',y='Price',kind='line')

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=fmri,x='timepoint',y='signal')

# %%
sns.catplot(data=tips,x='total_bill',y='day')

# %%
sns.catplot(data=tips,x='total_bill',y='smoker')

# %%
sns.catplot(data=tips,y="total_bill",x="time",kind="violin",hue="smoker")

# %%
sns.catplot(data=tips,y="total_bill",x="time",kind="box",hue="smoker")
